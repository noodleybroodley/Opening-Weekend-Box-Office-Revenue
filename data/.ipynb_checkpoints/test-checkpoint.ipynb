# %%
import pandas as pd

df = pd.read_csv('movies.csv')

# %%
df.head(30)
# Out:
#     Unnamed: 0  Rank                                        Release  \
# 0            0     1                              Avengers: Endgame
# 1            1     2                         Avengers: Infinity War
# 2            2     3     Star Wars: Episode VII - The Force Awakens
# 3            3     4        Star Wars: Episode VIII - The Last Jedi
# 4            4     5                                 Jurassic World
# 5            5     6                                   The Avengers
# 6            6     7                                  Black Panther
# 7            7     8                                  The Lion King
# 8            8     9                        Avengers: Age of Ultron
# 9            9    10                                  Incredibles 2
# 10          10    11                     Captain America: Civil War
# 11          11    12  Star Wars: Episode IX - The Rise of Skywalker
# 12          12    13                           Beauty and the Beast
# ...
